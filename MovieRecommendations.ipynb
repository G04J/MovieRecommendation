# %%
# Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
# Reading Dataset

# %%
df = pd.read_csv('movies.csv')
df1 = pd.read_csv('ratings.csv')

# %%
# Removing Warnings.

# %%
warnings.filterwarnings(action='ignore')

# %%
# EDA (Exploratory Data Analysis)

# %%
df
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
df1
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
df.describe()
# Out:
#              movieId
# count    9742.000000
# mean    42200.353623
# std     52160.494854
# min         1.000000
# 25%      3248.250000
# 50%      7300.000000
# 75%     76232.000000
# max    193609.000000

# %%
df1.describe()
# Out:
#               userId        movieId         rating     timestamp
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09

# %%
df.info
df1.info
# Out:
# <bound method DataFrame.info of         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]>

# %%
df.sample
df1.sample
# Out:
# <bound method NDFrame.sample of         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]>

# %%
df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df1.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
a = df.shape
b = df1.shape
a,b
# Out:
# ((9742, 3), (100836, 4))

# %%
df['title'].unique()
# Out:
# array(['Toy Story (1995)', 'Jumanji (1995)', 'Grumpier Old Men (1995)',
#        ..., 'Flint (2017)', 'Bungo Stray Dogs: Dead Apple (2018)',
#        'Andrew Dice Clay: Dice Rules (1991)'], dtype=object)

# %%
df['title'].value_counts().head(5)
# Out:
# Emma (1996)                               2
# War of the Worlds (2005)                  2
# Confessions of a Dangerous Mind (2002)    2
# Eros (2004)                               2
# Saturn 3 (1980)                           2
# Name: title, dtype: int64

# %%
df1['userId'].nunique()
# Out:
# 610

# %%
df1['movieId'].nunique()
# Out:
# 9724

# %%
df1
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
df1['rating'].unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
df1.groupby('movieId').count()['userId'].head(1)
len(df1[df1['movieId']==1])
# Out:
# 215

# %%
m = []
for i in df['genres']:
    i = i.split('|')
    m.append(i)

# a = df['genres']
# a

# %%
new_list = set()
# m[12][0]
for j in m:
    for z in j: 
        new_list.add(z)
        # new_list.append(z)

# new_list = list(dict.fromkeys(new_list))
new_list
# Out:
# {'(no genres listed)',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Children',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Fantasy',
#  'Film-Noir',
#  'Horror',
#  'IMAX',
#  'Musical',
#  'Mystery',
#  'Romance',
#  'Sci-Fi',
#  'Thriller',
#  'War',
#  'Western'}

# %%
len(new_list)
# Out:
# 20

# %%
df1.groupby('rating').count()['userId'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='rating'>

# %%
sns.countplot(df1['rating'])
# Out:
# <AxesSubplot:xlabel='rating', ylabel='count'>

# %%
df1[['rating','userId']].plot.line()
# Out:
# <AxesSubplot:>

# %%
df1.groupby('movieId').mean()['rating'].head(1)
# Out:
# movieId
# 1    3.92093
# Name: rating, dtype: float64

# %%
df1['movieId']==1
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 100831    False
# 100832    False
# 100833    False
# 100834    False
# 100835    False
# Name: movieId, Length: 100836, dtype: bool

# %%
df
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
df2 = pd.merge(df,df1)

# %%
df2
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
df2.shape
# Out:
# (100836, 6)

# %%
stat = pd.DataFrame(df2.groupby('title')['rating'].mean(),columns = ['rating'])

# %%
df2.groupby('title')['rating'].count().sort_values(ascending = False)
# Out:
# title
# Forrest Gump (1994)                          329
# Shawshank Redemption, The (1994)             317
# Pulp Fiction (1994)                          307
# Silence of the Lambs, The (1991)             279
# Matrix, The (1999)                           278
#                                             ...
# King Solomon's Mines (1950)                    1
# King Solomon's Mines (1937)                    1
# King Ralph (1991)                              1
# King Kong Lives (1986)                         1
# À nous la liberté (Freedom for Us) (1931)      1
# Name: rating, Length: 9719, dtype: int64

# %%
stat['count'] = df2.groupby('title')['rating'].count().sort_values(ascending = False)

# %%
stat
# Out:
#                                              rating  count
# title
# '71 (2014)                                 4.000000      1
# 'Hellboy': The Seeds of Creation (2004)    4.000000      1
# 'Round Midnight (1986)                     3.500000      2
# 'Salem's Lot (2004)                        5.000000      1
# 'Til There Was You (1997)                  4.000000      2
# ...                                             ...    ...
# eXistenZ (1999)                            3.863636     22
# xXx (2002)                                 2.770833     24
# xXx: State of the Union (2005)             2.000000      5
# ¡Three Amigos! (1986)                      3.134615     26
# À nous la liberté (Freedom for Us) (1931)  1.000000      1
#
# [9719 rows x 2 columns]

# %%
stat.sort_values(by = 'count', ascending = False)
# Out:
#                                              rating  count
# title
# Forrest Gump (1994)                        4.164134    329
# Shawshank Redemption, The (1994)           4.429022    317
# Pulp Fiction (1994)                        4.197068    307
# Silence of the Lambs, The (1991)           4.161290    279
# Matrix, The (1999)                         4.192446    278
# ...                                             ...    ...
# King Solomon's Mines (1950)                3.000000      1
# King Solomon's Mines (1937)                2.500000      1
# King Ralph (1991)                          1.500000      1
# King Kong Lives (1986)                     2.000000      1
# À nous la liberté (Freedom for Us) (1931)  1.000000      1
#
# [9719 rows x 2 columns]

# %%
print('hello')
pt =pd.pivot_table(df2, index = ['userId'], columns = ['title'],values='rating')
# Out:
# hello

# %%
pt
# Out:
# title   '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1              NaN                                      NaN
# 2              NaN                                      NaN
# 3              NaN                                      NaN
# 4              NaN                                      NaN
# 5              NaN                                      NaN
# ...            ...                                      ...
# 606            NaN                                      NaN
# 607            NaN                                      NaN
# 608            NaN                                      NaN
# 609            NaN                                      NaN
# 610            4.0                                      NaN
#
# title   'Round Midnight (1986)  'Salem's Lot (2004)  \
# userId
# 1                          NaN                  NaN
# 2                          NaN                  NaN
# 3                          NaN                  NaN
# ...

# %%
pt.columns
# Out:
# Index([''71 (2014)', ''Hellboy': The Seeds of Creation (2004)',
#        ''Round Midnight (1986)', ''Salem's Lot (2004)',
#        ''Til There Was You (1997)', ''Tis the Season for Love (2015)',
#        ''burbs, The (1989)', ''night Mother (1986)',
#        '(500) Days of Summer (2009)', '*batteries not included (1987)',
#        ...
#        'Zulu (2013)', '[REC] (2007)', '[REC]² (2009)',
#        '[REC]³ 3 Génesis (2012)',
#        'anohana: The Flower We Saw That Day - The Movie (2013)',
#        'eXistenZ (1999)', 'xXx (2002)', 'xXx: State of the Union (2005)',
#        '¡Three Amigos! (1986)', 'À nous la liberté (Freedom for Us) (1931)'],
#       dtype='object', name='title', length=9719)

# %%
pt['(500) Days of Summer (2009)']
# Out:
# userId
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
#       ...
# 606    NaN
# 607    NaN
# 608    NaN
# 609    NaN
# 610    3.5
# Name: (500) Days of Summer (2009), Length: 610, dtype: float64

# %%
a = pt.corrwith(pt['(500) Days of Summer (2009)']).sort_values(ascending = False).head(10)
# a['count'] = df2.groupby('title')['rating'].count()
a['count'] = stat['count']
a
# Out:
# title
# Red Rock West (1992)                                                                               1.0
# Think Like a Man (2012)                                                                            1.0
# Batman: The Dark Knight Returns, Part 1 (2012)                                                     1.0
# Nightmare on Elm Street, A (1984)                                                                  1.0
# Crush, The (1993)                                                                                  1.0
# The Shape of Water (2017)                                                                          1.0
# The Spectacular Now (2013)                                                                         1.0
# Fabulous Baker Boys, The (1989)                                                                    1.0
# Newsies (1992)                                                                                     1.0
# ...

# %%
pt.corrwith(pt["'Hellboy': The Seeds of Creation (2004)"]).sort_values(ascending = False)
# Out:
# title
# '71 (2014)                                  NaN
# 'Hellboy': The Seeds of Creation (2004)     NaN
# 'Round Midnight (1986)                      NaN
# 'Salem's Lot (2004)                         NaN
# 'Til There Was You (1997)                   NaN
#                                              ..
# eXistenZ (1999)                             NaN
# xXx (2002)                                  NaN
# xXx: State of the Union (2005)              NaN
# ¡Three Amigos! (1986)                       NaN
# À nous la liberté (Freedom for Us) (1931)   NaN
# Length: 9719, dtype: float64

# %%
m = '(500) Days of Summer (2009)'
sim_m = pt.corrwith(pt[m])

# %%
sim_m = pd.DataFrame(sim_m,columns = ['Similarity'])
sim_m['Similarity']
# Out:
# title
# '71 (2014)                                        NaN
# 'Hellboy': The Seeds of Creation (2004)           NaN
# 'Round Midnight (1986)                            NaN
# 'Salem's Lot (2004)                               NaN
# 'Til There Was You (1997)                         NaN
#                                                ...
# eXistenZ (1999)                             -0.388883
# xXx (2002)                                   0.831858
# xXx: State of the Union (2005)               1.000000
# ¡Three Amigos! (1986)                        0.572078
# À nous la liberté (Freedom for Us) (1931)         NaN
# Name: Similarity, Length: 9719, dtype: float64
